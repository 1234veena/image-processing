# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read an image
image = cv2.imread('C:/Users/User/Downloads/nature.jpg')

# Apply log transformation method
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))

# Specify the data type so that
# float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)

# Display both images
plt.imshow(image)
plt.show()
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10200/4201357975.py:10: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))
