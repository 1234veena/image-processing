# %%
import skimage.io
import skimage.util
import matplotlib.pyplot as plt
img = skimage.io.imread('photo.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()
print(a.shape)
# (225, 400, 3)

b = a // 1
c = a // 2
d=a//3
montage = skimage.util.montage([a, b, c,d], multichannel=True)
print(m.shape)
# (450, 800, 3)
plt.imshow(montage)
plt.axis('off')
plt.show()
# Out:
# (667, 1000, 3)
# (1334, 2000, 3)
