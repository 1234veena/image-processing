# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread,imshow
im1=imread('C:/Users/User/Downloads/nature.jpg')
imshow(im1)

# %%
im2=imread('C:/Users/User/Downloads/nature.jpg',as_gray=True)
imshow(im2)

# %%
im1.shape
# Out:
# (1155, 650, 3)

# %%
im2.shape
# Out:
# (1155, 650)

# %%
im1.size
# Out:
# 2252250

# %%
im2.size
# Out:
# 750750

# %%
print(im1.shape)
print(im2.shape)
# Out:
# (1155, 650, 3)
# (1155, 650)

# %%
print(im1.size)
print(im2.size)
# Out:
# 2252250
# 750750

# %%
pixel_features1=np.reshape(im2,(1155*650))
pixel_features1.shape,pixel_features1
# Out:
# ((750750,),
#  array([0.69901216, 0.68276039, 0.67295294, ..., 0.09506392, 0.07798588,
#         0.07631137]))

# %%
pixel_features2=np.reshape(im1,(1155*650*3))
pixel_features2.shape,pixel_features2
# Out:
# ((2252250,), array([177, 173, 234, ...,   9,  21,  35], dtype=uint8))

# %%
from PIL import Image,ImageStat
im=Image.open('C:/Users/User/Downloads/nature.jpg')
stat=ImageStat.Stat(im)
stat.var
# Out:
# [6896.004945706594, 5937.131470129296, 7622.0810662999265]

# %%
from PIL import Image,ImageStat
im=Image.open('C:/Users/User/Downloads/nature.jpg')
stat=ImageStat.Stat(im)
stat.mean
# Out:
# [96.7535357975358, 81.43773826173826, 102.60260006660006]

# %%
from PIL import Image,ImageStat
im=Image.open('C:/Users/User/Downloads/nature.jpg')
stat=ImageStat.Stat(im)
stat.median
# Out:
# [84, 53, 70]
