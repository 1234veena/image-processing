# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('sun.jpg')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.title('original')
plt.imshow(img)
plt.show()

kernel = np.ones((5,5),np.float32)/25  
img1 = cv2.boxFilter(img, 0, (2,2), img, (-1,-1), False, cv2.BORDER_DEFAULT)  
plt.title('box filterd')
plt.imshow(img1)
plt.show()
